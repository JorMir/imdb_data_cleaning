# %% [markdown]
# # IMDB Movie Data
#
# ### Jordan Miranda

# %% [markdown]
# In this notebook we'll be looking at a small dataset from IMDB that contains different movies with information about the movie such as genre, duration, country, etc.
#
# The goal within this notebook is to clean the dataset and prepare it for possible feature engineering and modelling later on. To clean this data we'll need to address any null values, clean/standardize values across the dataset, and possibly renaming columns to appropriately reflect the data they contain.
#
# We'll get started by importing the standard tools used for data manipulation with Python - `pandas` and `NumPy`.
# If any data visualization is necessary we'll import `Matplotlib` and `seaborn`.

# %%
# importing standard data tools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# Next we'll need to import the data we'll be working with.

# %%
# Loading in our dataset, including the delimiter used to separate the values
movies_df = pd.read_csv("data/messy_IMDB_dataset.csv", sep=";")
movies_df.head()
# Out:
#   IMBD title ID            Original titl�  Release year                 Genr�  \
# 0     tt0111161  The Shawshank Redemption    1995-02-10                 Drama
# 1     tt0068646             The Godfather    09 21 1972          Crime, Drama
# 2     tt0468569           The Dark Knight   23 -07-2008  Action, Crime, Drama
# 3     tt0071562    The Godfather: Part II    1975-09-25          Crime, Drama
# 4     tt0110912              Pulp Fiction    1994-10-28          Crime, Drama
#
#   Duration Country Content Rating              Director  Unnamed: 8  \
# 0      142     USA              R        Frank Darabont         NaN
# 1      175     USA              R  Francis Ford Coppola         NaN
# 2      152      US          PG-13     Christopher Nolan         NaN
# 3      220     USA              R  Francis Ford Coppola         NaN
# 4              USA              R     Quentin Tarantino         NaN
#
#           Income     Votes  Score
# 0     $ 28815245  2.278.845   9.3
# 1    $ 246120974  1.572.674   9.2
# 2   $ 1005455211  2.241.615    9.
# 3  $ 4o8,035,783  1.098.714  9,.0
# 4    $ 222831817  1.780.147  8,9f

# %% [markdown]
# ## Introductory Information on the Dataset
#
# Now that we've loaded the dataset, let's gather some basic info about the data such as its shape, datatypes, missing values (if any), and so on.

# %%
movies_df.shape
# Out:
# (101, 12)

# %% [markdown]
# This dataset contains 101 rows with 12 columns. Let's look at the names of the columns and their datatypes.

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   IMBD title ID   100 non-null    object
#  1   Original titl�  100 non-null    object
#  2   Release year    100 non-null    object
#  3   Genr�           100 non-null    object
#  4   Duration        99 non-null     object
#  5   Country         100 non-null    object
#  6   Content Rating  77 non-null     object
#  7   Director        100 non-null    object
#  8   Unnamed: 8      0 non-null      float64
#  9   Income          100 non-null    object
#  10   Votes          100 non-null    object
#  11  Score           100 non-null    object
# dtypes: float64(1), object(11)
# memory usage: 9.6+ KB

# %% [markdown]
# ## Initial Problems
#
# Here are the 11 columns (index excluded) that are in this dataset. Using `.info()` we can spot a few problems with the data already. Below we'll identify some of the initial concerns, with no particular priority (currently).
#
# ### Datatypes
#
# There are 10 columns with a datatype of `object` and 1 column having a datatype of `float`. From looking at the `.head()` we can see that the datatypes for some of these columns shouldn't be `object` but due to poor data entry formatting they've defaulted to `object`.
#
# One of the major tasks with this dataset will be to reformat the data entries so that they are consistent across each column and once done, assign the correct datatype to each respective column.
#
# ### Missing Values
#
# Looking across some columns we can see there are a few missing values. The column with the most missing values is `Unnamed: 8` with every value missing, second is `Content Rating` with 34 missing values. Some external research may need to be performed to source Content Ratings or we can impute the values based on EDA.
#
# ### Inconsistent Data Entry Formatting
#
# Looking at `Release year` we can see that the entries in this column vary in their ordering of MM/DD/YYYY. Looking at the `.head()` in the beginning of the dataset we also see inconsistent formatting with `Country`, `Income`, `Votes`, and `Score`.
#
# ### Inaccurate/Misspelled Column Titles
#
# Columns `Original title` and `Genre` contain characters that aren't displayed properly so we'll need to rename them to be readable.  We'll also need to correct the spelling of IMDB in the first column `IMBD title ID`.
#
# We can also see the `Release year` column isn't accurately representing the data in the column. The data within the column contains not just the release year but also the day and month, therefore the column's appropriate title would be `Release Date`. This will be the first problem we'll address as it's a simple fix.

# %% [markdown]
# ## Cleaning
#
# Now that we've identified some of the initial problems, we can start cleaning the data set. If during our cleaning we discover new issues we will make note of the issue and address it later.
#
# ### Columns
#
# As mentioned earlier, fixing the column titles will be one of the simpler fixes so we'll take care of that now.

# %%
# Getting all of the columns
movies_df.columns
# Out:
# Index(['IMBD title ID', 'Original titl�', 'Release year', 'Genr�', 'Duration',
#        'Country', 'Content Rating', 'Director', 'Unnamed: 8', 'Income',
#        ' Votes ', 'Score'],
#       dtype='object')

# %%
# Renaming the columns mentioned earlier
# using .rename and providing a dictionary of the columns that need fixing
movies_df.rename(columns={
    "IMBD title ID": "IMDB Title ID",
    movies_df.columns[1]: "Movie Title",
    "Release year": "Release Date",
    movies_df.columns[3]: "Genre",
    "Income": "Revenue",
    " Votes ": "Number of Votes"}, # Renaming income & votes as well for added clarity
inplace=True)

# %%
# Checking to see the renaming was done properly
movies_df.sample(3)
# Looks good!
# Out:
#    IMDB Title ID                 Movie Title Release Date  \
# 91     tt0086879                     Amadeus   1985-02-15
# 99     tt1832382     Jodaeiye Nader az Simin   2011-10-21
# 37     tt0103064  Terminator 2: Judgment Day   1991-12-19
#
#                         Genre Duration Country Content Rating        Director  \
# 91  Biography, Drama, History      160     USA              R    Milos Forman
# 99                      Drama      123    Iran          PG-13  Asghar Farhadi
# 37             Action, Sci-Fi      137     USA              R   James Cameron
#
#     Unnamed: 8      Revenue Number of Votes Score
# 91         NaN   $ 52066791         361.028   7.6
# 99         NaN   $ 22926076         214.165   7.4
# 37         NaN  $ 520884847         974.970   8.4

# %% [markdown]
# We've successfully renamed our problem columns. However, we do see there's 1 column leftover named `Unnamed: 8`. The entire column consists of null values and it's hard to identify without external context what this column would've been in this dataset. We're likely going to drop this column as there's no way we'll be able to impute any values into this column.
#
# Before dropping we'll confirm the column is full of null values.

# %%
# Finding number of null values in the unnamed column
unnamed_nulls = movies_df["Unnamed: 8"].isnull().sum()

# Taking the number of rows in the dataset
num_of_rows = movies_df.shape[0]

# If this returns True, all values in the unnamed column are null
unnamed_nulls == num_of_rows
# Out:
# True

# %% [markdown]
# We've double checked the column consists of all Null values. Let's drop the column.

# %%
# Dropping the column
movies_df.drop(columns="Unnamed: 8", inplace=True)

# Checking to see the drop was done successfully
movies_df.sample(3)
# Looks good!
# Out:
#     IMDB Title ID                  Movie Title Release Date  \
# 100     tt0045152          Singin' in the Rain   1953-02-05
# 68      tt0087843  Once Upon a Time in America   1984-09-28
# 30      tt0047478         Shichinin no samurai   1955-08-19
#
#                         Genre Duration Country Content Rating        Director  \
# 100  Comedy, Musical, Romance      103     USA            NaN   Stanley Donen
# 68               Crime, Drama      229     USA              R    Sergio Leone
# 30   Action, Adventure, Drama      207   Japan        Unrated  Akira Kurosawa
#
#        Revenue Number of Votes Score
# 100  $ 1864182         213.152   7.4
# 68   $ 5472914         302.317   8.0
# 30    $ 322773         307.958   8.6

# %% [markdown]
# We've successfully dropped the unnamed column. Let's continue on to missing values.
#
# ### Missing Values
#
# Now that we've dealt with the columns, let's approach our next problem - missing values.

# %%
# Getting the number of null values in each column
movies_df.isna().sum()
# Out:
# IMDB Title ID       1
# Movie Title         1
# Release Date        1
# Genre               1
# Duration            2
# Country             1
# Content Rating     24
# Director            1
# Revenue             1
# Number of Votes     1
# Score               1
# dtype: int64

# %%
# Locating the rows that contain null values
null_rows = movies_df.isnull().any(axis=1)

# Displaying the rows
movies_df[null_rows]
# Out:
#     IMDB Title ID                        Movie Title  \
# 13            NaN                                NaN
# 14      tt0133093                         The Matrix
# 27      tt0118799                   La vita B9 bella
# 28      tt6751668                       Gisaengchung
# 36      tt0110413                               Léon
# 40      tt7286456                              Joker
# 41      tt1675434                       Intouchables
# 47      tt0095327                     Hotaru no haka
# 48      tt0095765              Nuovo Cinema Paradiso
# 56      tt4154756             Avengers: Infinity War
# 58      tt4154796                  Avengers: Endgame
# 62      tt0047396                        Rear Window
# 63      tt2380307                               Coco
# 65      tt4633694  Spider-Man: Into the Spider-Verse
# 66      tt1187043                           3 Idiots
# 69      tt0032553                 The Great Dictator
# 70      tt0043014                       Sunset Blvd.
# 81      tt0066921                 A Clockwork Orange
# 86      tt0093058                  Full Metal Jacket
# 89      tt0033467                       Citizen Kane
# 90      tt8579674                               1917
# 92      tt0052357                            Vertigo
# 93      tt0053125                 North by Northwest
# 98      tt0059578         Per qualche dollaro in più
# 100     tt0045152                Singin' in the Rain
#
#                     Release Date                         Genre Duration  \
# 13                           NaN                           NaN      NaN
# 14                    1999-05-07                Action, Sci-Fi      NaN
# 27                    1997-12-20        Comedy, Drama, Romance      116
# 28                    2019-11-07       Comedy, Drama, Thriller      132
# 36                    1995-04-07          Action, Crime, Drama      110
# 40                    2019-10-03        Crime, Drama, Thriller      122
# 41                    2012-02-24      Biography, Comedy, Drama      112
# 47                    2015-10-11         Animation, Drama, War       89
# 48                    1988-11-17                         Drama      155
# 56                    2018-04-25     Action, Adventure, Sci-Fi      149
# 58                    2019-04-24      Action, Adventure, Drama      181
# 62                    1955-04-14             Mystery, Thriller      112
# 63                    2017-12-28  Animation, Adventure, Family      105
# 65                    2018-12-25  Animation, Action, Adventure      117
# 66                    2009-12-25                 Comedy, Drama      170
# 69                    1945-06-25            Comedy, Drama, War      125
# 70   The 6th of marzo, year 1951              Drama, Film-Noir      110
# 81                    1972-09-07          Crime, Drama, Sci-Fi      136
# 86                    1987-10-09                    Drama, War      116
# 89                    1948-11-25                Drama, Mystery      119
# 90                    2020-01-23                    Drama, War      119
# 92                    1958-11-18    Mystery, Romance, Thriller      128
# 93                    1959-10-28  Adventure, Mystery, Thriller      136
# 98                    1965-12-20                       Western      132
# 100                   1953-02-05      Comedy, Musical, Romance      103
#
#          Country Content Rating                         Director  \
# 13           NaN            NaN                              NaN
# 14           USA              R  Lana Wachowski, Lilly Wachowski
# 27        Italy1            NaN                  Roberto Benigni
# 28   South Korea            NaN                     Bong Joon Ho
# 36        France            NaN                       Luc Besson
# 40           USA            NaN                    Todd Phillips
# 41        France            NaN   Olivier Nakache, Éric Toledano
# 47         Japan            NaN                    Isao Takahata
# 48         Italy            NaN               Giuseppe Tornatore
# 56           USA            NaN         Anthony Russo, Joe Russo
# 58           USA            NaN         Anthony Russo, Joe Russo
# 62           USA            NaN                 Alfred Hitchcock
# 63           USA            NaN       Lee Unkrich, Adrian Molina
# 65           USA            NaN    Bob Persichetti, Peter Ramsey
# 66         India            NaN                  Rajkumar Hirani
# 69           USA            NaN                  Charles Chaplin
# 70           USA            NaN                     Billy Wilder
# 81            UK            NaN                  Stanley Kubrick
# 86            UK            NaN                  Stanley Kubrick
# 89           USA            NaN                     Orson Welles
# 90           USA            NaN                       Sam Mendes
# 92           USA            NaN                 Alfred Hitchcock
# 93           USA            NaN                 Alfred Hitchcock
# 98         Italy            NaN                     Sergio Leone
# 100          USA            NaN                    Stanley Donen
#
#           Revenue Number of Votes  Score
# 13            NaN             NaN    NaN
# 14    $ 465718588       1.632.315  ++8.7
# 27    $ 230098753         605.648    8.6
# 28    $ 257604912         470.931    8.6
# 36     $ 19552639       1.007.598    8.5
# 40   $ 1074251311         855.097    8.4
# 41    $ 426588510         736.691    8.4
# 47       $ 516962         225.438    8.3
# 48     $ 13826605         223.050    8.3
# 56   $ 2048359754         796.486    8.2
# 58   $ 2797800564         754.786    8.2
# 62     $ 37032034         432.390    8.1
# 63    $ 807083670         352.455    8.1
# 65    $ 375540831         335.892    8.1
# 66     $ 60262836         332.217    8.1
# 69       $ 969879         197.381    8.0
# 70       $ 299645         195.789    8.0
# 81     $ 26903440         740.301    7.8
# 86     $ 46357676         658.175    7.7
# 89      $ 1594107         389.322    7.6
# 90    $ 384857224         362.897    7.6
# 92      $ 7796389         352.786    7.5
# 93        $ 73446         291.628    7.5
# 98     $ 15000000         226.039    7.4
# 100     $ 1864182         213.152    7.4

# %% [markdown]
# There's one row that consists of entirely `NaN` values, we'll drop the column before dealing with the other `NaN` values in the `Content Rating` column.

# %%
# Dropping the row consisting of all NaNs
movies_df.drop(index=13, inplace=True)

# Resetting the index
movies_df.reset_index(drop=True, inplace=True)

# Seeing the remaining null values across all columns
movies_df.isna().sum()
# Out:
# IMDB Title ID       0
# Movie Title         0
# Release Date        0
# Genre               0
# Duration            1
# Country             0
# Content Rating     23
# Director            0
# Revenue             0
# Number of Votes     0
# Score               0
# dtype: int64

# %% [markdown]
# After dropping our row of all `NaN` values we're left with 1 null in the `Duration` column and 23 nulls in the `Content Rating` column.
#
# Since it's only one missing `Duration` we'll go ahead and pull the duration of the movie from Google and replace the null value directly.

# %%
# Finding the movie with a missing duration
movies_df[movies_df['Duration'].isna()]
# Out:
#    IMDB Title ID Movie Title Release Date           Genre Duration Country  \
# 13     tt0133093  The Matrix   1999-05-07  Action, Sci-Fi      NaN     USA
#
#    Content Rating                         Director      Revenue  \
# 13              R  Lana Wachowski, Lilly Wachowski  $ 465718588
#
#    Number of Votes  Score
# 13       1.632.315  ++8.7

# %% [markdown]
# Both Google and IMDB show that the movies duration was 2 hours and 16 minutes. The durations of the movies in the `Duration` column are formatted in minutes so we'll do the same.

# %%
# Calculating the matrix duration in minutes
matrix_duration = (60 * 2) + 16

# Inputting the matrix duration into the entry within the dataframe
movies_df["Duration"][movies_df.index == 13] = matrix_duration

# Checking that it worked
movies_df[movies_df.index == 13]
# Out:
#    IMDB Title ID Movie Title Release Date           Genre Duration Country  \
# 13     tt0133093  The Matrix   1999-05-07  Action, Sci-Fi      136     USA
#
#    Content Rating                         Director      Revenue  \
# 13              R  Lana Wachowski, Lilly Wachowski  $ 465718588
#
#    Number of Votes  Score
# 13       1.632.315  ++8.7

# %% [markdown]
# We've successfully filled in `The Matrix`'s duration. Let's check what remains for missing values now.

# %%
movies_df.isna().sum()
# Out:
# IMDB Title ID       0
# Movie Title         0
# Release Date        0
# Genre               0
# Duration            0
# Country             0
# Content Rating     23
# Director            0
# Revenue             0
# Number of Votes     0
# Score               0
# dtype: int64

# %% [markdown]
# The only column left containing null values is `Content Rating` with 23 null values.
#
# Since there are 23 null values, manually inputting each movie's content rating would be quite a tedious process as it makes up just under a quarter of all the data. If this dataset were much larger, sourcing 25% of the missing values and inputting them into a dataset wouldn't be feasible. For best practices, will try other methods before manual imputation.
#
# The first proposal to fill in these values will be to scrape the movie's content rating from IMDB. When going on IMDB's website, we can see that any given movie URL is in the following format: `imdb.com/title/(IMDB Title ID Here)/`. With each entry in our dataset having an `IMDB Title ID`, we can attach the `IMDB Title ID` to the imdb url to get the webpage and from there scrape for the movie's `Content Rating`.
#
# Let's begin.
#
# To start, we'll need to import BeautifulSoup, our webscraper of choice.

# %%
# Importing scraping libraries
import requests
from bs4 import BeautifulSoup

# Importing time to ensure we don't get rate limited
import time

# %%
# Ping IMDB page for the matrix
response = requests.get("https://www.imdb.com/title/tt0133093/")

# Turn the undecoded content into BS object 
soup = BeautifulSoup(response.content)

# Let's look at it
#soup
# I've commented out the soup here because the text in the response is incredibly long.
# If you'd like to see what it looks like yourself you can remove the # on the soup line and re-run this cell.
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><script></script><script>if(typeof uet === 'function'){ uet('bb', 'LoadAds', {wb: 1}); }</script><script>if(typeof uet === 'function'){ uet('be', 'LoadAds', {wb: 1}); }</script><script>if(typeof uex === 'function'){ uex('ld', 'LoadAds', {wb: 1}); }</script><script>if(typeof uet === 'function'){ uet('bb', 'LoadStyledComponents', {wb: 1}); }</script><style data-styled="" data-styled-version="5.2.1">.haXymx{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;margin-left:0.25rem;margin-right:auto;-webkit-order:1;-ms-flex-order:1;order:1;position:relative;}/*!sc*/
# @media screen and (min-width:1024px){.haXymx{margin-left:auto;margin-right:0.5rem;-webkit-order:0;-ms-flex-order:0;order:0;padding-left:0;}}/*!sc*/
# @media (hover:hover) and (pointer:fine){.haXymx:focus{outline:1px dashed currentColor;}.haXymx:focus:active{outline:0;}.haXymx:before,.haXymx:after{border-radius:10%;bottom:0;content:'';height:100%;left:0;margin:auto;opacity:0;position:absolute;right:0;top:0;-webkit-transition:opacity .2s cubic-bezier(1,1,1,1);transition:opacity .2s cubic-bezier(1,1,1,1);width:100%;}}/*!sc*/
# data-styled.g12[id="NavLogo-sc-e02kni-0"]{content:"haXymx,"}/*!sc*/
# .iRqsNC li:first-child > ._3CzPBqlWRmSAoWxtvQQ5Eo{border-top:none;}/*!sc*/
# data-styled.g18[id="SearchTypeahead-sc-112a48v-0"]{content:"iRqsNC,"}/*!sc*/
# .gRpUrl{position:relative;}/*!sc*/
# .gRpUrl.navbar__flyout__text-button-after-mobile,.gRpUrl .navbar__flyout__text-button-after-mobile{display:none;}/*!sc*/
# .gRpUrl .navbar__flyout__text-button-after-mobile > div{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .gRpUrl .navbar__flyout--menu{top:100%;position:absolute;margin-top:.25rem;}/*!sc*/
# .gRpUrl.gRpUrl.navbar__flyout--positionLeft .navbar__flyout--menu{left:0;right:auto;}/*!sc*/
# @media screen and (min-width:600px){.gRpUrl.navbar__flyout--breakpoint-m .navbar__flyout__icon-on-mobile{display:none;}.gRpUrl.navbar__flyout--breakpoint-m .navbar__flyout__text-button-after-mobile{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}}/*!sc*/
# @media screen and (min-width:1024px){.gRpUrl.navbar__flyout--breakpoint-l .navbar__flyout__icon-on-mobile{display:none;}.gRpUrl.navbar__flyout--breakpoint-l .navbar__flyout__text-button-after-mobile{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}}/*!sc*/
# @media screen and (min-width:1280px){.gRpUrl.navbar__flyout--breakpoint-xl .navbar__flyout__icon-on-mobile{display:none;}.gRpUrl.navbar__flyout--breakpoint-xl .navbar__flyout__text-button-after-mobile{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}}/*!sc*/
# .gRpUrl .navbar__flyout__button-pointer{-webkit-transition:-webkit-transform 0.2s;-webkit-transition:transform 0.2s;transition:transform 0.2s;-webkit-transform:rotateX(0);-ms-transform:rotateX(0);transform:rotateX(0);}/*!sc*/
# .gRpUrl.navbar__flyout--isVisible .navbar__flyout__button-pointer{-webkit-transform:rotateX(180deg);-ms-transform:rotateX(180deg);transform:rotateX(180deg);}/*!sc*/
# data-styled.g19[id="FlyoutMenu-sc-xq6xx0-0"]{content:"gRpUrl,"}/*!sc*/
# .fEgMct .search-category-selector__opener{border-radius:2px 0 0 2px;padding:0 0 0 0.5rem;min-height:32px;height:20px;border-right:1px solid rgba(0,0,0,0.3);}/*!sc*/
# .fEgMct _1L5qcXA4wOKR8LeHJgsqja{cursor:pointer;}/*!sc*/
# data-styled.g20[id="SearchCategorySelector__StyledContainer-sc-18f40f7-0"]{content:"fEgMct,"}/*!sc*/
# .hTfkOP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;margin:0;padding:0;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# @media screen and (min-width:600px){.hTfkOP{-webkit-transition:border 0.2s,background-color 0.2s,box-shadow 0.2s;transition:border 0.2s,background-color 0.2s,box-shadow 0.2s;}}/*!sc*/
# .hTfkOP .nav-search__search-input-container{width:100%;padding-right:3.5rem;}/*!sc*/
# .hTfkOP ._1-XI3_I8iwubPnQ1mmvW97{position:absolute;right:.35rem;min-width:2rem;cursor:pointer;top:.35rem;-webkit-transition:all 0.2s;transition:all 0.2s;}/*!sc*/
# @media screen and (min-width:600px){.hTfkOP.q2gp5sSzXI30d2n_razRe ._1-XI3_I8iwubPnQ1mmvW97{background:transparent;opacity:1;}}/*!sc*/
# .hTfkOP .imdb-header-search__input{background:transparent;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;outline:none;padding:1rem 1rem 1rem .75rem;width:100%;}/*!sc*/
# @media screen and (min-width:600px){.hTfkOP .imdb-header-search__input{padding:.375em 0 .375rem .5rem;}}/*!sc*/
# .hTfkOP .imdb-header-search__input::-ms-clear{display:none;}/*!sc*/
# data-styled.g21[id="SearchForm-sc-dxsip9-0"]{content:"hTfkOP,"}/*!sc*/
# .eAKYvb{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;left:0;margin:0;min-height:3.5rem;opacity:0;-webkit-transform:translateY(-10px);-ms-transform:translateY(-10px);transform:translateY(-10px);-webkit-transition:none;transition:none;-webkit-order:3;-ms-flex-order:3;order:3;pointer-events:none;position:absolute;top:0;visibility:hidden;width:100%;z-index:1;}/*!sc*/
# .eAKYvb .imdb-header-search__state-closer{-webkit-transform:scale(0.5);-ms-transform:scale(0.5);transform:scale(0.5);-webkit-transition:-webkit-transform 0.2s 0.1s;-webkit-transition:transform 0.2s 0.1s;transition:transform 0.2s 0.1s;display:inline;margin:.25rem;position:absolute;right:0;top:0;}/*!sc*/
# .eAKYvb .imdb-header-search__state,.eAKYvb .imdb-header-search__input,.eAKYvb .nav-search__search-submit{-moz-appearance:none;-webkit-appearance:none;-webkit-appearance:none;-moz-appearance:none;appearance:none;border:none;}/*!sc*/
# @media screen and (min-width:600px){.eAKYvb{-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;margin:0 0.5rem;padding:0;min-height:2.25rem;-webkit-order:3;-ms-flex-order:3;order:3;opacity:1;visibility:visible;pointer-events:auto;position:relative;-webkit-transform:translateY(0);-ms-transform:translateY(0);transform:translateY(0);}.eAKYvb .imdb-header-search__state,.eAKYvb .nav-search__search-submit{padding:0;}.eAKYvb .nav-search__search-submit:focus{outline:var(--ipt-focus-outline-on-base);outline-offset:1px;}.eAKYvb .imdb-header-search__state-closer{display:none;}}/*!sc*/
# data-styled.g22[id="SearchBar-sc-1nweg6x-0"]{content:"eAKYvb,"}/*!sc*/
# .byitLc{-webkit-transition:all 0.3s;transition:all 0.3s;opacity:1;-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);-webkit-order:3;-ms-flex-order:3;order:3;}/*!sc*/
# @media screen and (min-width:600px){.byitLc{-webkit-order:3;-ms-flex-order:3;order:3;}.byitLc.imdb-header-search__state-opener{display:none;}}/*!sc*/
# data-styled.g23[id="SearchBar__SearchLauncherButton-sc-1nweg6x-1"]{content:"byitLc,"}/*!sc*/
# .xMbAu:checked ~ .nav-search__search-container{opacity:1;-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);-webkit-transition:opacity 0.2s,-webkit-transform 0.2s;-webkit-transition:opacity 0.2s,transform 0.2s;transition:opacity 0.2s,transform 0.2s;visibility:visible;pointer-events:auto;z-index:100;}/*!sc*/
# .xMbAu:checked ~ .nav-search__search-container .nav-search__search-select,.xMbAu:checked ~ .nav-search__search-container .nav-search__search-submit{display:none;}/*!sc*/
# .xMbAu:checked ~ .nav-search__search-container .imdb-header-search__state-closer{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}/*!sc*/
# .xMbAu:checked ~ .nav-search__search-container ~ .SearchBar__SearchLauncherButton-sc-1nweg6x-1{-webkit-transform:scale(0.5);-ms-transform:scale(0.5);transform:scale(0.5);-webkit-transition:all 0.3s 0.3s;transition:all 0.3s 0.3s;opacity:0;}/*!sc*/
# data-styled.g24[id="SearchBar__MobileSearchStateToggle-sc-1nweg6x-2"]{content:"xMbAu,"}/*!sc*/
# .eGRdmJ._14--k36qjjvLW3hUWHDPb_{bottom:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;left:0;overflow:hidden;-webkit-perspective:70vh;-moz-perspective:70vh;-ms-perspective:70vh;perspective:70vh;pointer-events:none;position:fixed;right:0;top:0;visibility:hidden;z-index:100;}/*!sc*/
# .eGRdmJ .iRO9SK-8q3D8_287dhn28{box-shadow:none;box-sizing:border-box;height:100%;overflow-x:hidden;overflow-y:auto;position:relative;-webkit-transform:translateX(calc(-100% - 36px));-ms-transform:translateX(calc(-100% - 36px));transform:translateX(calc(-100% - 36px));-webkit-transform-origin:right center;-ms-transform-origin:right center;transform-origin:right center;-webkit-transition:all 0.3s,box-shadow 0s;transition:all 0.3s,box-shadow 0s;width:280px;z-index:2;-webkit-overflow-scroll:touch;}/*!sc*/
# .eGRdmJ ._1iCYg55DI6ds7d3KVrdYBX{box-sizing:border-box;display:block;height:100%;left:0;opacity:0;position:absolute;top:0;-webkit-transition:opacity 0.3s;transition:opacity 0.3s;visibility:hidden;width:100%;will-change:opacity;z-index:1;}/*!sc*/
# .eGRdmJ ._3rHHDKyPLOjL8tGKHWMRza{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;box-sizing:border-box;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;min-height:3.5rem;margin-bottom:0.5rem;padding:0.25rem;}/*!sc*/
# .eGRdmJ ._2RzUkzyrsjx_BPIQ5uoj5s{-webkit-touch-callout:none;-webkit-tap-highlight-color:transparent;}/*!sc*/
# ._146x-LuQBSfM9yosRvjSGF:checked ~ .Drawer__StyledContainer-sc-1h7cs9y-0._14--k36qjjvLW3hUWHDPb_{pointer-events:auto;visibility:visible;}/*!sc*/
# ._146x-LuQBSfM9yosRvjSGF:checked ~ .Drawer__StyledContainer-sc-1h7cs9y-0._14--k36qjjvLW3hUWHDPb_ > .iRO9SK-8q3D8_287dhn28{-webkit-transform:translateX(0);-ms-transform:translateX(0);transform:translateX(0);box-shadow:0px 11px 15px -7px rgba(var(--ipt-baseAlt-rgb),0.2),0px 24px 38px 3px rgba(var(--ipt-baseAlt-rgb),0.14),0px 9px 46px 8px rgba(var(--ipt-baseAlt-rgb),0.12);}/*!sc*/
# ._146x-LuQBSfM9yosRvjSGF:checked ~ .Drawer__StyledContainer-sc-1h7cs9y-0._14--k36qjjvLW3hUWHDPb_ > ._1iCYg55DI6ds7d3KVrdYBX{opacity:0.5;visibility:visible;}/*!sc*/
# @media screen and (min-width:1024px){.eGRdmJ .iRO9SK-8q3D8_287dhn28{width:100%;-webkit-transform:translateY(calc(-100%));-ms-transform:translateY(calc(-100%));transform:translateY(calc(-100%));padding:2rem 0;}.eGRdmJ ._3rHHDKyPLOjL8tGKHWMRza{background:none;max-width:1024px;margin:auto;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding:0 1rem;}.eGRdmJ ._3bRJYEaOz1BKUQYqW6yb29{max-width:1024px;margin:auto;}.eGRdmJ .WNY8DBPCS1ZbiSd7NoqdP{display:inline;}}/*!sc*/
# data-styled.g25[id="Drawer__StyledContainer-sc-1h7cs9y-0"]{content:"eGRdmJ,"}/*!sc*/
# .dvLykY .ipc-icon{opacity:0.5;-webkit-transition:opacity 0.2s;transition:opacity 0.2s;}/*!sc*/
# .dvLykY:hover .ipc-icon{opacity:1;}/*!sc*/
# @media screen and (max-width:479px){.dvLykY.nav-link--hideXS{display:none;}}/*!sc*/
# @media screen and (min-width:480px) and (max-width:599px){.dvLykY.nav-link--hideS{display:none;}}/*!sc*/
# @media screen and (min-width:600px) and (max-width:1023px){.dvLykY.nav-link--hideM{display:none;}}/*!sc*/
# @media screen and (min-width:1024px) and (max-width:1279px){.dvLykY.nav-link--hideL{display:none;}}/*!sc*/
# @media screen and (min-width:1280px){.dvLykY.nav-link--hideXL{display:none;}}/*!sc*/
# data-styled.g26[id="NavLink-sc-19k0khm-0"]{content:"dvLykY,"}/*!sc*/
# .gPCnBZ ._2vjThdvAXrHx6CofJjm03w{cursor:pointer;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-top:1px solid transparent;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;margin:0;padding:.5rem 1rem;-webkit-transition:color 0.1s ease-in,border-color 0.1s ease-in,opacity 0.12s ease-in;transition:color 0.1s ease-in,border-color 0.1s ease-in,opacity 0.12s ease-in;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# .gPCnBZ ._2vjThdvAXrHx6CofJjm03w:focus{outline:var(--ipt-focus-outline-on-baseAlt);outline-offset:1px;}/*!sc*/
# .gPCnBZ ._1tLXJMH37mh4UmvfVF8swF{-webkit-align-self:flex-start;-ms-flex-item-align:start;align-self:flex-start;padding-right:0.75rem;}/*!sc*/
# .gPCnBZ ._2aunAih-uMfbdgTUIjnQMd{-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;overflow:initial;overflow-wrap:break-word;padding-right:0.75rem;text-overflow:unset;white-space:break-spaces;}/*!sc*/
# .gPCnBZ ._2BeDp2pKthfMnxArm4lS0T{-webkit-transform:rotate(90deg);-ms-transform:rotate(90deg);transform:rotate(90deg);}/*!sc*/
# .gPCnBZ ._1tLXJMH37mh4UmvfVF8swF,.gPCnBZ ._2BeDp2pKthfMnxArm4lS0T{opacity:0.5;-webkit-transition:all 0.2s;transition:all 0.2s;}/*!sc*/
# .gPCnBZ ._2vjThdvAXrHx6CofJjm03w:focus ._2BeDp2pKthfMnxArm4lS0T,.gPCnBZ ._2vjThdvAXrHx6CofJjm03w:hover ._2BeDp2pKthfMnxArm4lS0T,.gPCnBZ ._2vjThdvAXrHx6CofJjm03w:focus ._1tLXJMH37mh4UmvfVF8swF,.gPCnBZ ._2vjThdvAXrHx6CofJjm03w:hover ._1tLXJMH37mh4UmvfVF8swF{opacity:1;}/*!sc*/
# .gPCnBZ ._1S9IOoNAVMPB2VikET3Lr2{overflow:hidden;border-bottom:1px solid transparent;-webkit-transition:border-color 0.1s ease-in,height 0.2s;transition:border-color 0.1s ease-in,height 0.2s;}/*!sc*/
# .gPCnBZ .s6lVaL5MYgQM-fYJ9KWp7:checked ~ span ._2vjThdvAXrHx6CofJjm03w ._1tLXJMH37mh4UmvfVF8swF{opacity:1;}/*!sc*/
# .gPCnBZ .s6lVaL5MYgQM-fYJ9KWp7:checked ~ span ._2vjThdvAXrHx6CofJjm03w ._2BeDp2pKthfMnxArm4lS0T{-webkit-transform:rotate(-90deg);-ms-transform:rotate(-90deg);transform:rotate(-90deg);}/*!sc*/
# .gPCnBZ .s6lVaL5MYgQM-fYJ9KWp7:checked ~ span ._1S9IOoNAVMPB2VikET3Lr2{display:block;}/*!sc*/
# .gPCnBZ:nth-of-type(1) ._2vjThdvAXrHx6CofJjm03w{border-top:none;}/*!sc*/
# @media screen and (min-width:1024px){.gPCnBZ.noMarginItem ._2vjThdvAXrHx6CofJjm03w{margin-top:0;}}/*!sc*/
# .gPCnBZ .ipc-list__item{height:auto;padding-top:.5rem;padding-bottom:.5rem;}/*!sc*/
# .gPCnBZ .ipc-list__item .ipc-list-item__text{white-space:initial;overflow-wrap:break-word;line-height:normal;}/*!sc*/
# @media screen and (min-width:1024px){.gPCnBZ{-webkit-flex-basis:33%;-ms-flex-preferred-size:33%;flex-basis:33%;max-width:33%;}.gPCnBZ ._2vjThdvAXrHx6CofJjm03w{border:none;margin-top:1.5rem;padding-top:.5rem;padding-bottom:.5rem;pointer-events:none;}.gPCnBZ .s6lVaL5MYgQM-fYJ9KWp7:checked ~ ._2Q0QZxgQqVpU0nQBqv1xlY ._2vjThdvAXrHx6CofJjm03w ._2aunAih-uMfbdgTUIjnQMd{color:inherit;}.gPCnBZ ._1S9IOoNAVMPB2VikET3Lr2{visibility:inherit;height:auto !important;border:0;}.gPCnBZ ._2BeDp2pKthfMnxArm4lS0T{display:none;}.gPCnBZ ._1tLXJMH37mh4UmvfVF8swF{color:var(--ipt-on-baseAlt-accent1-color);opacity:1;}.gPCnBZ .ipc-list--baseAlt .ipc-list__item:hover{background:none;-webkit-text-decoration:underline;text-decoration:underline;}}/*!sc*/
# @media screen and (max-width:479px){.gPCnBZ._2BpsDlqEMlo9unX-C84Nji--hideXS{display:none;}}/*!sc*/
# @media screen and (min-width:480px) and (max-width:599px){.gPCnBZ._2BpsDlqEMlo9unX-C84Nji--hideS{display:none;}}/*!sc*/
# @media screen and (min-width:600px) and (max-width:1023px){.gPCnBZ._2BpsDlqEMlo9unX-C84Nji--hideM{display:none;}}/*!sc*/
# @media screen and (min-width:1024px) and (max-width:1279px){.gPCnBZ._2BpsDlqEMlo9unX-C84Nji--hideL{display:none;}}/*!sc*/
# @media screen and (min-width:1280px){.gPCnBZ._2BpsDlqEMlo9unX-C84Nji--hideXL{display:none;}}/*!sc*/
# data-styled.g27[id="NavLinkCategory__StyledContainer-sc-1zvm8t-0"]{content:"gPCnBZ,"}/*!sc*/
# @media screen and (min-width:1024px){.egeBoN{-webkit-flex-basis:33%;-ms-flex-preferred-size:33%;flex-basis:33%;max-width:33%;}}/*!sc*/
# data-styled.g28[id="NavDynamicCategoryList__CategoryGroupContainer-sc-f186ms-0"]{content:"egeBoN,"}/*!sc*/
# @media screen and (min-width:1024px){.gIaMmK{-webkit-flex-basis:33%;-ms-flex-preferred-size:33%;flex-basis:33%;max-width:100%;}}/*!sc*/
# data-styled.g29[id="NavDynamicCategoryList__EmptyContainer-sc-f186ms-1"]{content:"gIaMmK,"}/*!sc*/
# @media screen and (min-width:1024px){.kEpZxO{max-width:100%;}}/*!sc*/
# data-styled.g30[id="NavDynamicCategoryList__GroupedCategoryComponent-sc-f186ms-2"]{content:"kEpZxO,"}/*!sc*/
# .ldBhao ._1cBEhLbHn9YeCkfPvo9USU{list-style:none;margin:0.5rem 0;opacity:0.2;}/*!sc*/
# .ldBhao ._3xW8qYlqcCPv5fOHeXBer5{margin-bottom:3rem;margin-top:1.5rem;padding:1rem;height:auto;}/*!sc*/
# @media screen and (min-width:1024px){.ldBhao{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}.ldBhao ._1BC0pBnjYqz3wST1u3CwmG{display:none;}.ldBhao ._3xW8qYlqcCPv5fOHeXBer5{-webkit-align-self:flex-start;-ms-flex-item-align:start;align-self:flex-start;display:none;}.ldBhao:focus{outline:var(--ipt-focus-outline-on-baseAlt);outline-offset:1px;}}/*!sc*/
# data-styled.g31[id="NavLinkCategoryList__StyledContainer-sc-13vymju-0"]{content:"ldBhao,"}/*!sc*/
# .bAyUxn{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# data-styled.g32[id="NavLinkCategoryList__LogoNavLink-sc-13vymju-1"]{content:"bAyUxn,"}/*!sc*/
# .fsOdPO{margin-top:.25rem;}/*!sc*/
# data-styled.g33[id="NavLinkCategoryList__TextNavLink-sc-13vymju-2"]{content:"fsOdPO,"}/*!sc*/
# .cuXMdR{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-order:0;-ms-flex-order:0;order:0;}/*!sc*/
# .cuXMdR.desktop{display:none;}/*!sc*/
# @media screen and (min-width:1024px){.cuXMdR{-webkit-order:1;-ms-flex-order:1;order:1;}.cuXMdR.mobile{display:none;}.cuXMdR.desktop{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}}/*!sc*/
# data-styled.g34[id="HamburgerMenu-sc-k5mvoq-0"]{content:"cuXMdR,"}/*!sc*/
# .lkfvZn{-webkit-order:6;-ms-flex-order:6;order:6;}/*!sc*/
# @media screen and (min-width:600px){.lkfvZn .navbar__user-menu__username-divider,.lkfvZn .navbar__user-menu__username{display:none;}}/*!sc*/
# @media screen and (min-width:1024px){.lkfvZn{-webkit-order:7;-ms-flex-order:7;order:7;}}/*!sc*/
# .lkfvZn .navbar__user-menu-toggle__button{padding-right:0.25rem;}/*!sc*/
# .lkfvZn .navbar__user-name{max-width:160px;text-overflow:ellipsis;white-space:nowrap;overflow:hidden;}/*!sc*/
# data-styled.g35[id="UserMenu-sc-1poz515-0"]{content:"lkfvZn,"}/*!sc*/
# .dAMWXo{-webkit-order:5;-ms-flex-order:5;order:5;display:none;}/*!sc*/
# @media screen and (min-width:1024px){.dAMWXo{-webkit-order:6;-ms-flex-order:6;order:6;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}}/*!sc*/
# .dAMWXo .imdb-header__watchlist-button-count{margin-left:0.5rem;background:var(--ipt-on-base-accent1-color);color:var(--ipt-on-accent1-color);padding:0 0.4rem;border-radius:10px;text-align:center;}/*!sc*/
# .dAMWXo .ipc-button__text{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g36[id="NavWatchlistButton-sc-1b65w5j-0"]{content:"dAMWXo,"}/*!sc*/
# .eSpONj{-webkit-order:4;-ms-flex-order:4;order:4;}/*!sc*/
# @media screen and (min-width:1024px){.eSpONj{-webkit-order:4;-ms-flex-order:4;order:4;}}/*!sc*/
# .eSpONj .navbar__imdbpro-menu-toggle__name{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .eSpONj .navbar__imdbpro-content .navbar__flyout--menu{background-image:url(//m.media-amazon.com/images/G/01/imdb/images/navbar/imdbpro_navbar_menu_bg-3083451252._V_.png);background-size:cover;padding-left:17px;padding-bottom:25px;padding-top:25px;color:white;font-weight:bold;}/*!sc*/
# .eSpONj .navbar__imdbpro-imdb-pro-ad{background-repeat:no-repeat;color:white;cursor:pointer;width:573px;overflow:hidden;border-radius:8px;left:initial;}/*!sc*/
# .eSpONj .navbar__imdbpro-imdb-pro-ad .imdb-pro-ad__content,.eSpONj .navbar__imdbpro-imdb-pro-ad .imdb-pro-ad__image{display:inline-block;}/*!sc*/
# .eSpONj .navbar__imdbpro-imdb-pro-ad .imdb-pro-ad__title{color:white;line-height:1.3em;margin-bottom:10px;}/*!sc*/
# .eSpONj .navbar__imdbpro-imdb-pro-ad .imdb-pro-ad__line{cursor:inherit;}/*!sc*/
# .eSpONj .navbar__imdbpro-imdb-pro-ad .imdb-pro-ad__link{display:inline-block;-webkit-text-decoration:none;text-decoration:none;vertical-align:middle;}/*!sc*/
# .eSpONj .navbar__imdbpro-imdb-pro-ad .imdb-pro-ad__content,.eSpONj .navbar__imdbpro-imdb-pro-ad .imdb-pro-ad__image{vertical-align:top;}/*!sc*/
# .eSpONj .navbar__imdbpro-imdb-pro-ad .imdb-pro-ad__content{font-family:'Arial';margin-left:15px;width:400px;}/*!sc*/
# .eSpONj .navbar__imdbpro-imdb-pro-ad .imdb-pro-ad__content .imdb-pro-ad__line{display:list-item;font-size:12px;list-style-position:inside;list-style-type:disc;margin:0px;padding:.1rem 0;}/*!sc*/
# .eSpONj .navbar__imdbpro-imdb-pro-ad .imdb-pro-ad__content .imdb-pro-ad__title{font-size:15px;}/*!sc*/
# .eSpONj .navbar__imdbpro-imdb-pro-ad .imdb-pro-new__button{margin-top:15px;}/*!sc*/
# .eSpONj .navbar__imdbpro-imdb-pro-ad .imdb-pro-new__button text{fill:#111111;font-size:13px;font-weight:normal;}/*!sc*/
# .eSpONj .navbar__imdbpro-imdb-pro-ad .imdb-pro-new__button svg:hover rect,.eSpONj .navbar__imdbpro-imdb-pro-ad .imdb-pro-new__button text:hover rect{fill:#f7dd95;}/*!sc*/
# .eSpONj .navbar__imdbpro-content .sub_nav{background-color:#f2f2f2;border-bottom-left-radius:10px;border-bottom-right-radius:10px;box-shadow:0 2px 5px rgba(0,0,0,0.6);color:#999;height:325px;}/*!sc*/
# .eSpONj .navbar__imdbpro-content .sub_nav h5{color:#A58500;margin:20px 0 10px;position:relative;}/*!sc*/
# data-styled.g37[id="NavProFlyout-sc-1cjctnc-0"]{content:"eSpONj,"}/*!sc*/
# .bVttoL{display:none;}/*!sc*/
# data-styled.g38[id="LegacyLoginNode-sc-1oajtws-0"]{content:"bVttoL,"}/*!sc*/
# .lGHHt.lGHHt.selected{color:rgb(255,255,255);color:var(--ipt-on-baseAlt-color,rgb(255,255,255));font-weight:bold;pointer-events:none;}/*!sc*/
# .lGHHt.lGHHt.disabled{color:rgba(255,255,255,0.5);color:var(--ipt-on-baseAlt-textDisabled-color,rgba(255,255,255,0.5));}/*!sc*/
# .lGHHt.lGHHt span{opacity:1;}/*!sc*/
# .lGHHt .language-menu-item-span{padding-right:0.5rem;}/*!sc*/
# .lGHHt .language-menu-item-icon{height:1.5rem;width:1.5rem;}/*!sc*/
# .lGHHt .selected-language-icon{color:rgb(245,197,24);color:var(--ipt-accent1-color,rgb(245,197,24));}/*!sc*/
# data-styled.g39[id="LanguageListItem__StyledListItem-sc-anvo6h-0"]{content:"lGHHt,"}/*!sc*/
# .hBVUfB{-webkit-order:7;-ms-flex-order:7;order:7;}/*!sc*/
# @media screen and (min-width:600px){.hBVUfB{-webkit-order:7;-ms-flex-order:7;order:7;}}/*!sc*/
# .hBVUfB .navbar__flyout__text-button-after-mobile{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;padding-right:0.25rem;}/*!sc*/
# .hBVUfB .disabled{pointer-events:none;}/*!sc*/
# data-styled.g42[id="LanguageSelector__StyledFlyoutMenu-sc-1hrlzs5-0"]{content:"hBVUfB,"}/*!sc*/
# .jxTuDX.jxTuDX{font-family:'Roboto','Helvetica','Arial',sans-serif;font-family:var(--ipt-font-family);font-size:.75rem;font-size:var(--ipt-type-overline-size,.75rem);font-weight:600;font-weight:var(--ipt-type-overline-weight,600);-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;-webkit-letter-spacing:.16667em;-moz-letter-spacing:.16667em;-ms-letter-spacing:.16667em;letter-spacing:.16667em;-webkit-letter-spacing:var(--ipt-type-overline-letterSpacing,.16667em);-moz-letter-spacing:var(--ipt-type-overline-letterSpacing,.16667em);-ms-letter-spacing:var(--ipt-type-overline-letterSpacing,.16667em);letter-spacing:var(--ipt-type-overline-letterSpacing,.16667em);line-height:1rem;line-height:var(--ipt-type-overline-lineHeight,1rem);text-transform:uppercase;text-transform:var(--ipt-type-overline-textTransform,uppercase);}/*!sc*/
# data-styled.g43[id="LanguageSelector__SectionHeader-sc-1hrlzs5-1"]{content:"jxTuDX,"}/*!sc*/
# .dtcBHE{padding:0.25rem;margin:0;position:relative;z-index:1000;min-height:3.5rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;}/*!sc*/
# .dtcBHE a{color:inherit;}/*!sc*/
# .dtcBHE .navbar__inner{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;width:100vw;margin:0;}/*!sc*/
# @media screen and (min-width:600px){.dtcBHE .navbar__inner{padding:0 .75rem;}}/*!sc*/
# @media screen and (min-width:1024px){.dtcBHE .navbar__inner{width:100%;margin:0 auto;}}/*!sc*/
# .dtcBHE label{margin-bottom:0;}/*!sc*/
# .dtcBHE li{margin-bottom:0;}/*!sc*/
# data-styled.g45[id="Root__Header-sc-7p0yen-0"]{content:"dtcBHE,"}/*!sc*/
# .htSMJL{border:1px solid rgba(var(--ipt-on-baseAlt-rgb),.16);-webkit-order:5;-ms-flex-order:5;order:5;width:1px;height:2rem;margin:0 .5rem;}/*!sc*/
# @media screen and (max-width:600px){.htSMJL{display:none;-webkit-order:8;-ms-flex-order:8;order:8;}}/*!sc*/
# data-styled.g46[id="Root__Separator-sc-7p0yen-1"]{content:"htSMJL,"}/*!sc*/
# *,*::before,*::after{box-sizing:border-box;}/*!sc*/
# html{background:rgb(0,0,0);background:var(--ipt-baseAlt-bg);}/*!sc*/
# html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,main,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}/*!sc*/
# article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section{display:block;}/*!sc*/
# *[hidden]{display:none;}/*!sc*/
# body{line-height:1;}/*!sc*/
# ol,ul{list-style:none;}/*!sc*/
# blockquote,q{quotes:none;}/*!sc*/
# blockquote:before,blockquote:after,q:before,q:after{content:'';content:none;}/*!sc*/
# table{border-collapse:collapse;border-spacing:0;}/*!sc*/
# data-styled.g48[id="sc-global-dfwuIR1"]{content:"sc-global-dfwuIR1,"}/*!sc*/
# .fWxmdE{position:relative;}/*!sc*/
# data-styled.g51[id="BaseLayout__NextPageContentContainer-sc-180q5jf-0"]{content:"fWxmdE,"}/*!sc*/
# .liWbxi{width:100%;}/*!sc*/
# data-styled.g82[id="IMDbEditorialSingle__StyledSlateCard-sc-ppbgrx-0"]{content:"liWbxi,"}/*!sc*/
# .jxUJiS{width:100%;position:relative;}/*!sc*/
# .jxUJiS.height-page{height:50vh;}/*!sc*/
# .jxUJiS.height-feature{height:20rem;}/*!sc*/
# data-styled.g83[id="CenteredLoader__Container-sc-4sxbyz-0"]{content:"jxUJiS,"}/*!sc*/
# .dFydMW{margin:auto;position:absolute;top:0;right:0;bottom:0;left:0;}/*!sc*/
# data-styled.g84[id="CenteredLoader__StyledLoader-sc-4sxbyz-1"]{content:"dFydMW,"}/*!sc*/
# .kHlJyu{display:block;}/*!sc*/
# @media screen and (min-width:976px){.kHlJyu{display:none;}}/*!sc*/
# data-styled.g112[id="GenresAndPlot__TextContainerBreakpointXS_TO_M-sc-cum89p-0"]{content:"kHlJyu,"}/*!sc*/
# .eqlIrG{display:none;}/*!sc*/
# @media screen and (min-width:976px) and (max-width:1279px){.eqlIrG{display:block;}}/*!sc*/
# data-styled.g113[id="GenresAndPlot__TextContainerBreakpointL-sc-cum89p-1"]{content:"eqlIrG,"}/*!sc*/
# .eqbKRZ{display:none;}/*!sc*/
# @media screen and (min-width:1280px){.eqbKRZ{display:block;}}/*!sc*/
# data-styled.g114[id="GenresAndPlot__TextContainerBreakpointXL-sc-cum89p-2"]{content:"eqbKRZ,"}/*!sc*/
# .LKJMs{margin-top:0.5rem;}/*!sc*/
# @media screen and (min-width:480px){.LKJMs{margin-top:0;}}/*!sc*/
# data-styled.g115[id="GenresAndPlot__GenreChip-sc-cum89p-3"]{content:"LKJMs,"}/*!sc*/
# .hYGwcP{font-family:'Roboto','Helvetica','Arial',sans-serif;font-family:var(--ipt-font-family);font-size:1rem;font-size:var(--ipt-type-body-size,1rem);font-weight:400;font-weight:var(--ipt-type-body-weight,400);-webkit-letter-spacing:.03125em;-moz-letter-spacing:.03125em;-ms-letter-spacing:.03125em;letter-spacing:.03125em;-webkit-letter-spacing:var(--ipt-type-body-letterSpacing,.03125em);-moz-letter-spacing:var(--ipt-type-body-letterSpacing,.03125em);-ms-letter-spacing:var(--ipt-type-body-letterSpacing,.03125em);letter-spacing:var(--ipt-type-body-letterSpacing,.03125em);line-height:1.5rem;line-height:var(--ipt-type-body-lineHeight,1.5rem);text-transform:none;text-transform:var(--ipt-type-body-textTransform,none);}/*!sc*/
# data-styled.g118[id="GenresAndPlot__Plot-sc-cum89p-6"]{content:"hYGwcP,"}/*!sc*/
# .hTqGWn{padding:1rem 0 1rem;}/*!sc*/
# .hTqGWn .GenresAndPlot__GenresChipList-sc-cum89p-4 + .GenresAndPlot__Plot-sc-cum89p-6,.hTqGWn .GenresAndPlot__OffsetChipList-sc-cum89p-5 + .GenresAndPlot__Plot-sc-cum89p-6{margin-top:.75rem;}/*!sc*/
# data-styled.g120[id="GenresAndPlot__ContentParent-sc-cum89p-8"]{content:"hTqGWn,"}/*!sc*/
# .jYLNaj{margin-left:calc(-1 * var(--ipt-pageMargin,1rem));padding-left:1rem;padding-left:var(--ipt-pageMargin,1rem);margin-right:calc(-1 * var(--ipt-pageMargin,1rem));padding-right:1rem;padding-right:var(--ipt-pageMargin,1rem);}/*!sc*/
# .jYLNaj:not(:first-child){margin-top:1rem;}/*!sc*/
# data-styled.g122[id="Keywords__PlotKeywords-sc-ke3vmf-0"]{content:"jYLNaj,"}/*!sc*/
# .bcsfkB{color:rgb(14,99,190);color:var(--ipt-on-base-accent2-color,rgb(14,99,190));}/*!sc*/
# data-styled.g123[id="Keywords__SeeMore-sc-ke3vmf-1"]{content:"bcsfkB,"}/*!sc*/
# .gtSxnm{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding:1rem;padding:var(--ipt-pageMargin,1rem);}/*!sc*/
# data-styled.g124[id="EmptySection__EmptyRecentlyViewedSection-sc-zo1hbb-0"]{content:"gtSxnm,"}/*!sc*/
# .jUAGsa{--ipt-base-rgb:255,255,255;--ipt-base-bg:rgb(255,255,255);--ipt-base-color:rgb(255,255,255);--ipt-base-shade1-rgb:250,250,250;--ipt-base-shade1-bg:rgb(250,250,250);--ipt-base-shade1-color:rgb(250,250,250);--ipt-base-shade2-rgb:240,240,240;--ipt-base-shade2-bg:rgb(240,240,240);--ipt-base-shade2-color:rgb(240,240,240);--ipt-base-shade3-rgb:255,255,255;--ipt-base-shade3-bg:rgb(255,255,255);--ipt-base-shade3-color:rgb(255,255,255);--ipt-on-base-rgb:0,0,0;--ipt-on-base-color:rgb(0,0,0);--ipt-on-base-accent1-rgb:245,197,24;--ipt-on-base-accent1-color:rgb(245,197,24);--ipt-on-base-accent2-rgb:14,99,190;--ipt-on-base-accent2-color:rgb(14,99,190);--ipt-on-base-accent3-rgb:189,36,4;--ipt-on-base-accent3-color:rgb(189,36,4);--ipt-on-base-accent4-rgb:0,138,0;--ipt-on-base-accent4-color:rgb(0,138,0);--ipt-on-base-textPrimary-opacity:0.87;--ipt-on-base-textPrimary-color:rgba(0,0,0,0.87);--ipt-on-base-textSecondary-opacity:0.54;--ipt-on-base-textSecondary-color:rgba(0,0,0,0.54);--ipt-on-base-textHint-opacity:0.38;--ipt-on-base-textHint-color:rgba(0,0,0,0.38);--ipt-on-base-textDisabled-opacity:0.38;--ipt-on-base-textDisabled-color:rgba(0,0,0,0.38);--ipt-on-base-textIcon-opacity:0.5;--ipt-on-base-textIcon-color:rgba(0,0,0,0.5);--ipt-base-border-opacity:0.12;--ipt-base-hover-opacity:0.08;--ipt-base-pressed-opacity:0.16;--ipt-base-stripes-opacity:0.04;--ipt-base-border-color:rgba(0,0,0,0.12);--ipt-base-hover-color:rgba(0,0,0,0.08);--ipt-base-pressed-color:rgba(0,0,0,0.16);--ipt-base-stripes-color:rgba(0,0,0,0.04);--ipt-baseAlt-rgb:0,0,0;--ipt-baseAlt-bg:rgb(0,0,0);--ipt-baseAlt-color:rgb(0,0,0);--ipt-baseAlt-shade1-rgb:31,31,31;--ipt-baseAlt-shade1-bg:rgb(31,31,31);--ipt-baseAlt-shade1-color:rgb(31,31,31);--ipt-baseAlt-shade2-rgb:26,26,26;--ipt-baseAlt-shade2-bg:rgb(26,26,26);--ipt-baseAlt-shade2-color:rgb(26,26,26);--ipt-baseAlt-shade3-rgb:18,18,18;--ipt-baseAlt-shade3-bg:rgb(18,18,18);--ipt-baseAlt-shade3-color:rgb(18,18,18);--ipt-on-baseAlt-rgb:255,255,255;--ipt-on-baseAlt-color:rgb(255,255,255);--ipt-on-baseAlt-accent1-rgb:245,197,24;--ipt-on-baseAlt-accent1-color:rgb(245,197,24);--ipt-on-baseAlt-accent2-rgb:87,153,239;--ipt-on-baseAlt-accent2-color:rgb(87,153,239);--ipt-on-baseAlt-accent3-rgb:251,60,60;--ipt-on-baseAlt-accent3-color:rgb(251,60,60);--ipt-on-baseAlt-accent4-rgb:103,173,75;--ipt-on-baseAlt-accent4-color:rgb(103,173,75);--ipt-on-baseAlt-textPrimary-opacity:1;--ipt-on-baseAlt-textPrimary-color:rgba(255,255,255,1);--ipt-on-baseAlt-textSecondary-opacity:0.7;--ipt-on-baseAlt-textSecondary-color:rgba(255,255,255,0.7);--ipt-on-baseAlt-textHint-opacity:0.5;--ipt-on-baseAlt-textHint-color:rgba(255,255,255,0.5);--ipt-on-baseAlt-textDisabled-opacity:0.5;--ipt-on-baseAlt-textDisabled-color:rgba(255,255,255,0.5);--ipt-on-baseAlt-textIcon-opacity:1;--ipt-on-baseAlt-textIcon-color:rgba(255,255,255,1);--ipt-baseAlt-border-opacity:0.2;--ipt-baseAlt-hover-opacity:0.08;--ipt-baseAlt-pressed-opacity:0.32;--ipt-baseAlt-stripes-opacity:0.12;--ipt-baseAlt-border-color:rgba(255,255,255,0.2);--ipt-baseAlt-hover-color:rgba(255,255,255,0.08);--ipt-baseAlt-pressed-color:rgba(255,255,255,0.32);--ipt-baseAlt-stripes-color:rgba(255,255,255,0.12);--ipt-accent1-rgb:245,197,24;--ipt-accent1-bg:rgb(245,197,24);--ipt-accent1-color:rgb(245,197,24);--ipt-on-accent1-rgb:0,0,0;--ipt-on-accent1-color:rgb(0,0,0);--ipt-accent2-rgb:14,99,190;--ipt-accent2-bg:rgb(14,99,190);--ipt-accent2-color:rgb(14,99,190);--ipt-on-accent2-rgb:255,255,255;--ipt-on-accent2-color:rgb(255,255,255);--ipt-accent3-rgb:189,36,4;--ipt-accent3-bg:rgb(189,36,4);--ipt-accent3-color:rgb(189,36,4);--ipt-on-accent3-rgb:255,255,255;--ipt-on-accent3-color:rgb(255,255,255);--ipt-accent4-rgb:0,114,7;--ipt-accent4-bg:rgb(0,114,7);--ipt-accent4-color:rgb(0,114,7);--ipt-on-accent4-rgb:255,255,255;--ipt-on-accent4-color:rgb(255,255,255);font-family:'Roboto','Helvetica','Arial',sans-serif;font-family:var(--ipt-font-family);font-size:1rem;font-size:var(--ipt-type-body-size,1rem);font-weight:400;font-w ...
# data-styled.g126[id="RecentlyViewedItems__RecentlyViewedContainer-sc-1kscdxa-0"]{content:"jUAGsa,"}/*!sc*/
# @media screen and (min-width:1024px){.eMHvqh{display:none;}}/*!sc*/
# data-styled.g127[id="IMDbNextAdSlot__IMDbNextAdSlotMain-sc-are5cb-0"]{content:"eMHvqh,"}/*!sc*/
# .DuCJB{display:none;}/*!sc*/
# @media screen and (min-width:1024px){.DuCJB{display:block;}}/*!sc*/
# data-styled.g128[id="IMDbNextAdSlot__IMDbNextAdSlotSidebar-sc-are5cb-1"]{content:"DuCJB,"}/*!sc*/
# .dczLOa{min-height:auto;margin:0 auto;background:rgba(var(--ipt-accent3-rgb),0.5);color:var(--ipt-on-accent3-color);height:100%;}/*!sc*/
# data-styled.g139[id="PremiumSlot-sc-pyz1bq-0"]{content:"dczLOa,"}/*!sc*/
# .hsuFaL{overflow:hidden;background:rgb(31,31,31);background:var(--ipt-baseAlt-shade1-bg,rgb(31,31,31));}/*!sc*/
# data-styled.g140[id="ATFWrapper__StyledPageBackground-sc-ll9gc8-0"]{content:"hsuFaL,"}/*!sc*/
# @media screen and (min-width:1024px){.lceHLS{display:none;}}/*!sc*/
# data-styled.g143[id="AroundTheWeb__AroundTheWebMain-sc-n0ai1p-2"]{content:"lceHLS,"}/*!sc*/
# .jWLcmW{display:none;}/*!sc*/
# @media screen and (min-width:1024px){.jWLcmW{display:block;}}/*!sc*/
# data-styled.g144[id="AroundTheWeb__AroundTheWebSidebar-sc-n0ai1p-3"]{content:"jWLcmW,"}/*!sc*/
# .dDTCRM{position:relative;min-height:50vh;}/*!sc*/
# data-styled.g147[id="BTFWrapper__RelativePageBackground-sc-1g8jgrg-0"]{content:"dDTCRM,"}/*!sc*/
# .fKIzsM{position:relative;overflow:hidden;}/*!sc*/
# data-styled.g148[id="BTFWrapper__MainColumnContent-sc-1g8jgrg-1"]{content:"fKIzsM,"}/*!sc*/
# .eBmPPG{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# @media screen and (min-width:1024px) and (max-width:1279px){.eBmPPG{padding-left:.5rem;}}/*!sc*/
# @media screen and (min-width:1280px){.eBmPPG{padding-left:.75rem;}}/*!sc*/
# @media screen and (max-width:1024px){.eBmPPG{padding-top:var(--ipc-pageSection-bottomMargin);}}/*!sc*/
# data-styled.g149[id="BTFWrapper__SidebarContainer-sc-1g8jgrg-2"]{content:"eBmPPG,"}/*!sc*/
# .gpPyfC > * + *{margin-top:2.5rem;margin-bottom:2.5rem;}/*!sc*/
# .gpPyfC > * + *:last-child{margin-bottom:0;}/*!sc*/
# data-styled.g150[id="BTFWrapper__SidebarMainContent-sc-1g8jgrg-3"]{content:"gpPyfC,"}/*!sc*/
# .bTEHgX{position:-webkit-sticky;position:-webkit-sticky;position:sticky;top:0;margin-top:.75rem;margin-bottom:1.5rem;}/*!sc*/
# data-styled.g151[id="BTFWrapper__StickyBlock-sc-1g8jgrg-4"]{content:"bTEHgX,"}/*!sc*/
# .hsughJ{position:relative;}/*!sc*/
# data-styled.g152[id="MainDetailPageLayout__StyledPageBackground-sc-13rp3wh-0"]{content:"hsughJ,"}/*!sc*/
# .fGHwms{background:var(--ipt-base-bg);}/*!sc*/
# data-styled.g153[id="MainColumnSlot-sc-899m3c-0"]{content:"fGHwms,"}/*!sc*/
# .jULuNF{display:block;}/*!sc*/
# data-styled.g154[id="DidYouKnowCard__StyledHTMLContent-sc-1wpmufy-0"]{content:"jULuNF,"}/*!sc*/
# .kYsONC{padding-right:0;}/*!sc*/
# data-styled.g155[id="DidYouKnowCard__StyledListCard-sc-1wpmufy-1"]{content:"kYsONC,"}/*!sc*/
# .kbwbLF{display:block;}/*!sc*/
# .kbwbLF p{margin-top:0px;margin-bottom:0px;}/*!sc*/
# data-styled.g157[id="Quotes__StyledHTMLContent-sc-ff1m6h-1"]{content:"kbwbLF,"}/*!sc*/
# .ghnHWT{min-height:36px;}/*!sc*/
# data-styled.g188[id="RatingGroup__StyledRatingStarGroup-sc-1vuc0kn-0"]{content:"ghnHWT,"}/*!sc*/
# .jwvNUS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:.5rem 0;margin-bottom:-1rem;}/*!sc*/
# .jwvNUS.justify--space-between{-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# .jwvNUS.justify--space-around{-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;}/*!sc*/
# .jwvNUS.justify--left{-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}/*!sc*/
# .jwvNUS.justify--right{-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;}/*!sc*/
# .jwvNUS.both-card-actions > .card-action-button{margin-left:-0.25rem;padding-right:0.5rem;padding-left:0.5rem;}/*!sc*/
# .jwvNUS.both-card-actions > .card-action-icon{margin-right:-0.25rem;}/*!sc*/
# .jwvNUS > .card-action-button{text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g191[id="BottomActions__CardActionsWrapper-sc-uiehgt-0"]{content:"jwvNUS,"}/*!sc*/
# .hTlrud{-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;color:inherit;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-text-decoration-style:none;text-decoration-style:none;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .hTlrud:hover{opacity:0.8;}/*!sc*/
# .hTlrud .poster{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}/*!sc*/
# .hTlrud .content{-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;padding-left:1rem;}/*!sc*/
# .hTlrud .headline{-webkit-box-orient:vertical;font-family:'Roboto','Helvetica','Arial',sans-serif;font-family:var(--ipt-font-family);font-size:1rem;font-size:var(--ipt-type-body-size,1rem);font-weight:400;font-weight:var(--ipt-type-body-weight,400);-webkit-letter-spacing:.03125em;-moz-letter-spacing:.03125em;-ms-letter-spacing:.03125em;letter-spacing:.03125em;-webkit-letter-spacing:var(--ipt-type-body-letterSpacing,.03125em);-moz-letter-spacing:var(--ipt-type-body-letterSpacing,.03125em);-ms-letter-spacing:var(--ipt-type-body-letterSpacing,.03125em);letter-spacing:var(--ipt-type-body-letterSpacing,.03125em);line-height:1.5rem;line-height:var(--ipt-type-body-lineHeight,1.5rem);text-transform:none;text-transform:var(--ipt-type-body-textTransform,none);margin:0;display:-webkit-box;-webkit-line-clamp:4;overflow:hidden;}/*!sc*/
# .hTlrud .metadata{font-family:'Roboto','Helvetica','Arial',sans-serif;font-family:var(--ipt-font-family);font-size:.75rem;font-size:var(--ipt-type-copyright-size,.75rem);font-weight:400;font-weight:var(--ipt-type-copyright-weight,400);-webkit-letter-spacing:.03333em;-moz-letter-spacing:.03333em;-ms-letter-spacing:.03333em;letter-spacing:.03333em;-webkit-letter-spacing:var(--ipt-type-copyright-letterSpacing,.03333em);-moz-letter-spacing:var(--ipt-type-copyright-letterSpacing,.03333em);-ms-letter-spacing:var(--ipt-type-copyright-letterSpacing,.03333em);letter-spacing:var(--ipt-type-copyright-letterSpacing,.03333em);line-height:1rem;line-height:var(--ipt-type-copyright-lineHeight,1rem);text-transform:none;text-transform:var(--ipt-type-copyright-textTransform,none);margin-top:.25rem;}/*!sc*/
# .hTlrud .source{margin-left:.5rem;}/*!sc*/
# data-styled.g201[id="NewsItem__Container-sc-7p8k9m-0"]{content:"hTlrud,"}/*!sc*/
# .kSzuBT:not(:first-child){margin-top:1rem;}/*!sc*/
# data-styled.g203[id="PlotSection__PlotLinks-sc-1hc6syk-0"]{content:"kSzuBT,"}/*!sc*/
# .uzdyc{margin-left:1rem;margin-left:var(--ipt-pageMargin,1rem);margin-right:1rem;margin-right:var(--ipt-pageMargin,1rem);}/*!sc*/
# data-styled.g204[id="SidebarSlot__StyledBaseSlot-sc-ysywbf-0"]{content:"uzdyc,"}/*!sc*/
# .izvVhq{-webkit-transition:background 0.3s;transition:background 0.3s;}/*!sc*/
# .izvVhq .VideoSlate__title div:first-of-type{height:unset;}/*!sc*/
# data-styled.g236[id="VideoSlate__StyledSlateCard-sc-qxjuas-0"]{content:"izvVhq,"}/*!sc*/
# .cgqHBf{margin:0 1rem;margin:0 var(--ipt-pageMargin,1rem);}/*!sc*/
# data-styled.g237[id="styles__MetaDataContainer-sc-12uhu9s-0"]{content:"cgqHBf,"}/*!sc*/
# .hPfcyc{font-family:'Roboto','Helvetica','Arial',sans-serif;font-family:var(--ipt-font-family);font-size:.875rem;font-size:var(--ipt-type-bodySmall-size,.875rem);font-weight:400;font-weight:var(--ipt-type-bodySmall-weight,400);-webkit-letter-spacing:.01786em;-moz-letter-spacing:.01786em;-ms-letter-spacing:.01786em;letter-spacing:.01786em;-webkit-letter-spacing:var(--ipt-type-bodySmall-letterSpacing,.01786em);-moz-letter-spacing:var(--ipt-type-bodySmall-letterSpacing,.01786em);-ms-letter-spacing:var(--ipt-type-bodySmall-letterSpacing,.01786em);letter-spacing:var(--ipt-type-bodySmall-letterSpacing,.01786em);line-height:1.25rem;line-height:var(--ipt-type-bodySmall-lineHeight,1.25rem);text-transform:none;text-transform:var(--ipt-type-bodySmall-textTransform,none);}/*!sc*/
# data-styled.g238[id="UserReviewAuthor__AuthorContainer-sc-qb9r2z-0"]{content:"hPfcyc,"}/*!sc*/
# .klqpHF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-top:1rem;margin-bottom:.75rem;}/*!sc*/
# data-styled.g239[id="UserReviewSummary__SummaryContainer-sc-kfza1v-0"]{content:"klqpHF,"}/*!sc*/
# .jNqoHr{font-family:'Roboto','Helvetica','Arial',sans-serif;font-family:var(--ipt-font-family);font-size:1.25rem;font-size:var(--ipt-type-headline6-size,1.25rem);font-weight:600;font-weight:var(--ipt-type-headline6-weight,600);-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;-webkit-letter-spacing:.0125em;-moz-letter-spacing:.0125em;-ms-letter-spacing:.0125em;letter-spacing:.0125em;-webkit-letter-spacing:var(--ipt-type-headline6-letterSpacing,.0125em);-moz-letter-spacing:var(--ipt-type-headline6-letterSpacing,.0125em);-ms-letter-spacing:var(--ipt-type-headline6-letterSpacing,.0125em);letter-spacing:var(--ipt-type-headline6-letterSpacing,.0125em);line-height:1.5rem;line-height:var(--ipt-type-headline6-lineHeight,1.5rem);text-transform:none;text-transform:var(--ipt-type-headline6-textTransform,none);}/*!sc*/
# data-styled.g240[id="UserReviewSummary__Summary-sc-kfza1v-1"]{content:"jNqoHr,"}/*!sc*/
# .iWtBpi{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# data-styled.g246[id="UserReviewActionContainer__ActionContainer-sc-184juar-0"]{content:"iWtBpi,"}/*!sc*/
# .guXGaG{text-align:right;}/*!sc*/
# data-styled.g247[id="UserReviewActionContainer__ShareButtonContainer-sc-184juar-1"]{content:"guXGaG,"}/*!sc*/
# .gPBbOI{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# data-styled.g248[id="UserReviewsFeaturedReview__ReviewHeaderContainer-sc-pyneo1-0"]{content:"gPBbOI,"}/*!sc*/
# .dQtnyx{margin:0;margin-bottom:1.5rem;}/*!sc*/
# data-styled.g249[id="UserReviewsFeaturedReview__SpeechBubble-sc-pyneo1-1"]{content:"dQtnyx,"}/*!sc*/
# .ktUycW{margin-top:-.25rem;}/*!sc*/
# @media screen and (max-width:479px){.ktUycW{margin-left:1rem;margin-bottom:1rem;-webkit-align-self:flex-start;-ms-flex-item-align:start;align-self:flex-start;}}/*!sc*/
# @media screen and (min-width:480px){.ktUycW{-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;margin-bottom:1.5rem;}}/*!sc*/
# @media screen and (min-width:600px){.ktUycW{margin-top:.25rem;}}/*!sc*/
# data-styled.g250[id="AddReviewActionButton__AddReviewButton-sc-11e8do2-0"]{content:"ktUycW,"}/*!sc*/
# .izUxOB{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding-right:1rem;padding-right:var(--ipt-pageMargin,1rem);}/*!sc*/
# @media screen and (max-width:479px){.izUxOB{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;}}/*!sc*/
# data-styled.g251[id="UserReviewsHeader__Header-sc-k61aee-0"]{content:"izUxOB,"}/*!sc*/
# .epUObA{padding-top:0;padding-bottom:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g253[id="FeatureHeader__PositionedResponsiveButton-sc-1mxxvnl-1"]{content:"epUObA,"}/*!sc*/
# .hVkwxo{margin-top:-.75rem;padding-top:0;padding-bottom:0;}/*!sc*/
# @media screen and (min-width:600px){.hVkwxo{margin-top:.25rem;}}/*!sc*/
# data-styled.g254[id="FeatureHeader__PositionedIconButton-sc-1mxxvnl-2"]{content:"hVkwxo,"}/*!sc*/
# .iywpty{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;margin:0 1rem;margin:0 var(--ipt-pageMargin,1rem);}/*!sc*/
# data-styled.g255[id="Storyline__StorylineWrapper-sc-1b58ttw-0"]{content:"iywpty,"}/*!sc*/
# .esngIX{margin-top:1rem;}/*!sc*/
# data-styled.g256[id="Storyline__StorylineMetaDataList-sc-1b58ttw-1"]{content:"esngIX,"}/*!sc*/
# .bmSqjg{margin-bottom:1.5rem;}/*!sc*/
# data-styled.g263[id="Header__PhotoSectionTitle-sc-14opf2q-0"]{content:"bmSqjg,"}/*!sc*/
# .jVGlmF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding-right:1rem;padding-right:var(--ipt-pageMargin,1rem);}/*!sc*/
# data-styled.g264[id="Header-sc-14opf2q-1"]{content:"jVGlmF,"}/*!sc*/
# @media screen and (min-width:480px) and (max-width:599px){.eWuVbf{grid-column:span 6;}}/*!sc*/
# data-styled.g265[id="NewsSection__StyledNewsItem-sc-1k3o8su-0"]{content:"eWuVbf,"}/*!sc*/
# @supports (-webkit-line-clamp:2){.hZDsCc{display:-webkit-box;-webkit-line-clamp:2;-webkit-box-orient:vertical;overflow:hidden;}}/*!sc*/
# data-styled.g277[id="Faqs__StyledLink-sc-10p3xr2-0"]{content:"hZDsCc,"}/*!sc*/
# .hhfXZz{padding:0;}/*!sc*/
# data-styled.g280[id="AnswersCTA__AnswerLink-sc-1bimoq7-0"]{content:"hhfXZz,"}/*!sc*/
# .lcPyMW{margin-left:var(--ipt-pageMargin,1rem);margin-right:var(--ipt-pageMargin,1rem);margin-bottom:1.5rem;}/*!sc*/
# ...
#         if (window && window.ad_utils && window.ad_utils.makeAtfSlotsCall) {
#             window.ad_utils.makeAtfSlotsCall(
#                 undefined, 'undefined', '', undefined
#             );
#         }
#     </script><section class="ipc-page-background ipc-page-background--base MainDetailPageLayout__StyledPageBackground-sc-13rp3wh-0 hsughJ"><section class="ipc-page-background ipc-page-background--baseAlt ATFWrapper__StyledPageBackground-sc-ll9gc8-0 hsuFaL"><div id="ipc-wrap-background-id" style="position:absolute;width:100%;height:100%"></div><section class="ipc-page-background ipc-page-background--baseAlt inline20-page-background"><div class="ipc-page-content-container ipc-page-content-container--center" role="presentation"><div class="nas-slot"><div class="slot_wrapper nas-spacing nas-dark" id="inline20_responsive_wrapper" style="position:relative;display:none"><div></div></div></div></div></section><div class="ipc-page-content-container ipc-page-content-container--center" role="presentation"></div><div class="ipc-page-content-container ipc-page-content-container--center" role="presentation"><section class="ipc-page-background ipc-page-background--baseAlt Hero__StyledPageBackground-sc-kvkd64-0 kQLMSa"><section class="ipc-page-section ipc-page-section--baseAlt ipc-page-section--tp-xs ipc-page-section--bp-xs Hero__HeroParent-sc-kvkd64-1 jtIUNN"><div class="TitleBlock__Container-sc-1nlhx7j-0 hglRHk"><div class="TitleBlock__TitleContainer-sc-1nlhx7j-1 jxsVNt"><div class="TitleBlock__SeriesParentLinkWrapper-sc-1nlhx7j-3 itQvtY"></div><h1 class="TitleHeader__TitleText-sc-1wu6n3d-0 dxSWFG" data-testid="hero-title-block__title" textlength="10">The Matrix</h1><div class="TitleBlock__TitleMetaDataContainer-sc-1nlhx7j-2 hWHMKr"><ul class="ipc-inline-list ipc-inline-list--show-dividers TitleBlockMetaData__MetaDataList-sc-12ein40-0 dxizHm baseAlt" data-testid="hero-title-block__metadata" role="presentation"><li class="ipc-inline-list__item" role="presentation"><a class="ipc-link ipc-link--baseAlt ipc-link--inherit-color TitleBlockMetaData__StyledTextLink-sc-12ein40-1 rgaOW" href="/title/tt0133093/releaseinfo?ref_=tt_ov_rdat">1999</a><span class="TitleBlockMetaData__ListItemText-sc-12ein40-2 jedhex">1999</span></li><li class="ipc-inline-list__item" role="presentation"><a class="ipc-link ipc-link--baseAlt ipc-link--inherit-color TitleBlockMetaData__StyledTextLink-sc-12ein40-1 rgaOW" href="/title/tt0133093/parentalguide/certificates?ref_=tt_ov_pg">14A</a><span class="TitleBlockMetaData__ListItemText-sc-12ein40-2 jedhex">14A</span></li><li class="ipc-inline-list__item" role="presentation">2<!-- -->h<!-- --> <!-- -->16<!-- -->m</li></ul></div></div><div class="RatingBar__RatingContainer-sc-85l9wd-0 hNqCJh TitleBlock__HideableRatingBar-sc-1nlhx7j-4 bhTVMj"><div class="RatingBar__ButtonContainer-sc-85l9wd-1 idYUsR"><div class="RatingBarButtonBase__ContentWrap-sc-15v8ssr-0 jQXoLQ rating-bar__base-button" data-testid="hero-rating-bar__aggregate-rating"><div class="RatingBarButtonBase__Header-sc-15v8ssr-1 bufoWn">IMDb RATING</div><a aria-disabled="false" aria-label="View User Ratings" class="ipc-button ipc-button--single-padding ipc-button--center-align-content ipc-button--default-height ipc-button--core-baseAlt ipc-button--theme-baseAlt ipc-button--on-textPrimary ipc-text-button RatingBarButtonBase__Button-sc-15v8ssr-2 jjcqHZ" href="/title/tt0133093/ratings/?ref_=tt_ov_rt" role="button" tabindex="0"><div class="ipc-button__text"><div class="RatingBarButtonBase__ButtonContentWrap-sc-15v8ssr-3 jodtvN"><div class="RatingBarButtonBase__IconWrapper-sc-15v8ssr-4 dwhzFZ"><svg class="ipc-icon ipc-icon--star AggregateRatingButton__RatingIcon-sc-1ll29m0-4 iAOIoP" fill="currentColor" height="24" id="iconContext-star" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 17.27l4.15 2.51c.76.46 1.69-.22 1.49-1.08l-1.1-4.72 3.67-3.18c.67-.58.31-1.68-.57-1.75l-4.83-.41-1.89-4.46c-.34-.81-1.5-.81-1.84 0L9.19 8.63l-4.83.41c-.88.07-1.24 1.17-.57 1.75l3.67 3.18-1.1 4.72c-.2.86.73 1.54 1.49 1.08l4.15-2.5z"></path></svg></div><div class="AggregateRatingButton__ContentWrap-sc-1ll29m0-0 hmJkIS"><div class="AggregateRatingBut ...
# "METACORTEX" on the outside of the building, but a sign inside the building has it spelled "META CORTECHS". Featurettes suggest that the name was changed to avoid an expensive legal issue; evidently one of the signs was missed.</div></div><div class="ipc-overflowText-overlay"><svg class="ipc-icon ipc-icon--more-horiz ipc-overflowText-overlay__affordance" fill="currentColor" height="24" id="iconContext-more-horiz" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M6 10c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm12 0c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm-6 0c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></svg></div></div></div><a aria-label="See more" class="ipc-metadata-list-item__icon-link" href="/title/tt0133093/goofs?tab=gf&amp;ref_=tt_trv_gf" target=""><svg class="ipc-icon ipc-icon--chevron-right" fill="currentColor" height="24" id="iconContext-chevron-right" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.29 6.71a.996.996 0 0 0 0 1.41L13.17 12l-3.88 3.88a.996.996 0 1 0 1.41 1.41l4.59-4.59a.996.996 0 0 0 0-1.41L10.7 6.7c-.38-.38-1.02-.38-1.41.01z"></path></svg></a></li></ul></div><div class="ipc-list-card--border-line ipc-list-card--tp-none ipc-list-card--bp-none ipc-list-card DidYouKnowCard__StyledListCard-sc-1wpmufy-1 kYsONC ipc-list-card--base"><ul class="ipc-metadata-list ipc-metadata-list--dividers-none ipc-metadata-list--base" role="presentation"><li class="ipc-metadata-list__item ipc-metadata-list__item--stacked ipc-metadata-list-item--link" data-testid="didyouknow-quote" role="presentation"><a class="ipc-metadata-list-item__label ipc-metadata-list-item__label--link" href="/title/tt0133093/quotes/?ref_=tt_trv_qu" rel="" target="">Quotes</a><div class="ipc-metadata-list-item__content-container"><div class="ipc-overflowText ipc-overflowText--listCard ipc-overflowText--height-short ipc-overflowText--short ipc-overflowText--base" role="presentation"><div class="ipc-html-content ipc-html-content--base Quotes__StyledHTMLContent-sc-ff1m6h-1 kbwbLF"><div><p><a class="ipc-link ipc-link--base" href="/name/nm0000401/?ref_=tt_trv_qu">Morpheus</a>: This is your last chance. After this, there is no turning back. You take the blue pill - the story ends, you wake up in your bed and believe whatever you want to believe. You take the red pill - you stay in Wonderland and I show you how deep the rabbit-hole goes.</p></div></div><div class="ipc-overflowText-overlay"><svg class="ipc-icon ipc-icon--more-horiz ipc-overflowText-overlay__affordance" fill="currentColor" height="24" id="iconContext-more-horiz" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M6 10c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm12 0c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm-6 0c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></svg></div></div></div><a aria-label="See more" class="ipc-metadata-list-item__icon-link" href="/title/tt0133093/quotes/?ref_=tt_trv_qu" target=""><svg class="ipc-icon ipc-icon--chevron-right" fill="currentColor" height="24" id="iconContext-chevron-right" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.29 6.71a.996.996 0 0 0 0 1.41L13.17 12l-3.88 3.88a.996.996 0 1 0 1.41 1.41l4.59-4.59a.996.996 0 0 0 0-1.41L10.7 6.7c-.38-.38-1.02-.38-1.41.01z"></path></svg></a></li></ul></div><div class="ipc-list-card--border-line ipc-list-card--tp-none ipc-list-card--bp-none ipc-list-card DidYouKnowCard__StyledListCard-sc-1wpmufy-1 kYsONC ipc-list-card--base"><ul class="ipc-metadata-list ipc-metadata-list--dividers-none ipc-metadata-list--base" role="presentation"><li class="ipc-metadata-list__item ipc-metadata-list__item--stacked ipc-metadata-list-item--link" role="present ...
# There's a 'secret' link on the page that requests a password.</div></div><div class="ipc-overflowText-overlay"><svg class="ipc-icon ipc-icon--more-horiz ipc-overflowText-overlay__affordance" fill="currentColor" height="24" id="iconContext-more-horiz" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M6 10c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm12 0c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm-6 0c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></svg></div></div></div><a aria-label="See more" class="ipc-metadata-list-item__icon-link" href="/title/tt0133093/crazycredits?tab=cz&amp;ref_=tt_trv_cc" target=""><svg class="ipc-icon ipc-icon--chevron-right" fill="currentColor" height="24" id="iconContext-chevron-right" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.29 6.71a.996.996 0 0 0 0 1.41L13.17 12l-3.88 3.88a.996.996 0 1 0 1.41 1.41l4.59-4.59a.996.996 0 0 0 0-1.41L10.7 6.7c-.38-.38-1.02-.38-1.41.01z"></path></svg></a></li></ul></div><div class="ipc-list-card--border-line ipc-list-card--tp-none ipc-list-card--bp-none ipc-list-card DidYouKnowCard__StyledListCard-sc-1wpmufy-1 kYsONC ipc-list-card--base"><ul class="ipc-metadata-list ipc-metadata-list--dividers-none ipc-metadata-list--base" role="presentation"><li class="ipc-metadata-list__item ipc-metadata-list__item--stacked ipc-metadata-list-item--link" role="presentation"><a class="ipc-metadata-list-item__label ipc-metadata-list-item__label--link" href="/title/tt0133093/alternateversions?tab=cz&amp;ref_=tt_trv_alt" rel="" target="">Alternate versions</a><div class="ipc-metadata-list-item__content-container"><div class="ipc-overflowText ipc-overflowText--listCard ipc-overflowText--height-short ipc-overflowText--short ipc-overflowText--base" role="presentation"><div class="ipc-html-content ipc-html-content--base DidYouKnowCard__StyledHTMLContent-sc-1wpmufy-0 jULuNF"><div>Because 'The Matrix' was filmed in Australia the Region 4 (Australia) DVD release includes a more comprehensive Australian based list of credits.</div></div><div class="ipc-overflowText-overlay"><svg class="ipc-icon ipc-icon--more-horiz ipc-overflowText-overlay__affordance" fill="currentColor" height="24" id="iconContext-more-horiz" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M6 10c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm12 0c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm-6 0c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></svg></div></div></div><a aria-label="See more" class="ipc-metadata-list-item__icon-link" href="/title/tt0133093/alternateversions?tab=cz&amp;ref_=tt_trv_alt" target=""><svg class="ipc-icon ipc-icon--chevron-right" fill="currentColor" height="24" id="iconContext-chevron-right" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.29 6.71a.996.996 0 0 0 0 1.41L13.17 12l-3.88 3.88a.996.996 0 1 0 1.41 1.41l4.59-4.59a.996.996 0 0 0 0-1.41L10.7 6.7c-.38-.38-1.02-.38-1.41.01z"></path></svg></a></li></ul></div><div class="ipc-list-card--border-line ipc-list-card--tp-none ipc-list-card--bp-none ipc-list-card DidYouKnowCard__StyledListCard-sc-1wpmufy-1 kYsONC ipc-list-card--base"><ul class="ipc-metadata-list ipc-metadata-list--dividers-none ipc-metadata-list--base" role="presentation"><li class="ipc-metadata-list__item ipc-metadata-list__item--stacked ipc-metadata-list-item--link" role="presentation"><a class="ipc-metadata-list-item__label ipc-metadata-list-item__label--link" href="/title/tt0133093/movieconnections/?ref_=tt_trv_cnn" rel="" target="">Connections</a><div class="ipc-metadata-list-item__content-container"><div class="ipc-overflowText ipc-overflowText--listCard ipc-overflowText--height-short ipc-overflowText--shor ...

# %%
# Looking at the HTML, the movie's duration and rating are in a list class
# We'll pull all lists with this class and take the 2nd and 3rd items in the list through slicing
info_list = soup.find_all("li", {"class": "ipc-inline-list__item"})

# Slicing the 2 li elements of importance and assigning them to a new variable
year_rating_duration = info_list[1:3]

# Looking into the contents of the 2 li elements
year_rating_duration
# Out:
# [<li class="ipc-inline-list__item" role="presentation"><a class="ipc-link ipc-link--baseAlt ipc-link--inherit-color TitleBlockMetaData__StyledTextLink-sc-12ein40-1 rgaOW" href="/title/tt0133093/parentalguide/certificates?ref_=tt_ov_pg">14A</a><span class="TitleBlockMetaData__ListItemText-sc-12ein40-2 jedhex">14A</span></li>,
#  <li class="ipc-inline-list__item" role="presentation">2<!-- -->h<!-- --> <!-- -->16<!-- -->m</li>]

# %%
variable_rating = str(year_rating_duration[0]).split(">")[2]

matrix_rating = variable_rating.split("<")[0]

matrix_rating
# Out:
# '14A'

# %%
r_d_header_test2 = soup.find_all("span", {"class": "TitleBlockMetaData__ListItemText-sc-12ein40-2 jedhex"})
r_d_header_test2
# Out:
# [<span class="TitleBlockMetaData__ListItemText-sc-12ein40-2 jedhex">1999</span>,
#  <span class="TitleBlockMetaData__ListItemText-sc-12ein40-2 jedhex">14A</span>]
